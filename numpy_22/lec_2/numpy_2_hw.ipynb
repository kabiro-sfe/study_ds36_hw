# %%
import pandas as pd

# %% [markdown]
# ### Задание 1

# %%
data = pd.read_csv('ml-25m/ratings.csv')

res = data[(data['rating']==5)].value_counts(['movieId']).head(1).to_frame()


mov = pd.read_csv('ml-25m/movies.csv')

result = res.merge(mov, on='movieId', how='left')

result.filter(['movieId', 'title'])
# Out:
#    movieId                             title
# 0      318  Shawshank Redemption, The (1994)

# %% [markdown]
# ### Задание 2

# %%
data = pd.read_csv('10/power.csv')


data_fil = (data[((data['country'] == 'Latvia') |  
                  (data['country'] == 'Lithuania') |  
                  (data['country'] == 'Estonia') ) & # отбор по странам
                 ((data['year'] < 2010) & (data['year'] > 2005)) &  # отбор по категориям
                    ((data['category'] == 4) | (data['category'] == 12) | (data['category'] == 21)) & # отбор по категориям
                    (data['quantity'] > 0)]) # без отрицательных значений

res = data_fil.groupby(['country']).sum().filter(['country', 'quantity'])
res
# Out:
#            quantity
# country
# Estonia     42184.0
# Latvia      35860.0
# Lithuania   86511.0

# %% [markdown]
# ### Задание 3

# %%
pd.read_html('https://fortrader.org/quotes')[0]
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  88.27      -0.07         -0.07        NaN
# 1       USDRUB Курс рубля к доллару  74.33      -0.27         -0.36        NaN

# %%
pd.read_html('https://fortrader.org/quotes')[3]
# Out:
#                                         Название      Цена  Изменение  \
# 0                                  ВТБ Акции ВТБ  0.049015  +0.000320
# 1                         Газпром Акции газпрома    295.20      +2.34
# 2                            Лукойл Акции Лукойл   6 650.0      -34.0
# 3                        Роснефть Акции Роснефти    575.90      -5.20
# 4                       Сбербанк Акции Сбербанка    303.72      +1.09
# 5           Сургутнефтегаз Акции Сургутнефтегаза    35.580     -0.185
# 6                      Норникель Акции Норникель    24 794       +280
# 7                       Аэрофлот Акции Аерофлота     68.84      +0.34
# 8                    Северсталь Акции Северсталь  1 624.00     +63.00
# 9                    Транснефть Акции Транснефть   174 600     +2 150
# 10             Ростелеком Курс акций ростелекома     99.12      -2.92
# 11                      РУСАЛ Акции РУСАЛ (RUAL)    49.675     +0.705
# 12      Детский мир iDreamSky Technology Limited    143.84      +1.12
# 13             Петропавловск Акции Петропавловск     23.00      -0.02
# 14                    Алроса Акции АЛРОСА (ALRS)   130.930     +3.050
# 15                    Магнит Акции Магнит (MGNT)   5 324.0      -20.0
# 16                        НМЛК Акции НЛМК (NLMK)   233.540     +7.420
# 17                  М.видео Акции М.видео (MVID)    618.40     -13.60
# 18    Газпром нефть Акции "Газпром нефть" (SIBN)    438.60      -3.80
# 19                        НМТП Акции НМТП (NMTP)    6.9500    +0.0250
# 20            Полиметалл Акции Полиметалл (POLY)  1 624.00     -10.70
# 21        Полюс Золото Акции Полюс Золото (PLZL)  14 209.5     -339.5
# 22                  НОВАТЭК Акции НОВАТЭК (NVTK)  1 613.40     -25.20
# 23                РусГидро Акции РусГидро (HYDR)    0.8340    +0.0090
# 24                Татнефть Акции Татнефть (TATN)    518.50      -3.40
# 25        АФК Система Акции АФК "Система" (AFKS)    31.147     -0.008
# 26                                 МТС Акции МТС    318.95      +0.75
# 27                Башнефть Акции Башнефть (BANE)   1 477.0      +16.0
# 28                    Яндекс Акции Яндекс (YNDX)   5 242.6     -111.6
# 29  X5 Retail Group Акции X5 Retail Group (FIVE)  2 476.00     -19.50
# 30                  ФСК ЕЭС Акции ФСК ЕЭС (FEES)   0.22878   +0.00096
# 31                      Мечел Акции Мечел (MTLR)     76.80      +2.11
# 32                МосБиржа Акции МосБиржа (MOEX)    171.50      -0.98
# 33              Интер РАО Акции Интер РАО (IRAO)      4.69      +0.01
# 34              Mail.ru Акции Mail.ru (MAIL, ДР)  1 617.00     -12.80
# 35                        Киви Акции Киви (QIWI)     759.0       -2.0
# 36                  Лента Акции Лента (LNTA, ДР)    247.80      -1.20
# 37            Тинькофф Акции Тинькофф (TCSG, др)  6 599.00     -74.00
# 38                        Озон Акции Озон (Ozon)  4 130.00     +27.00
#
#     Изменение(%)  Обновлено
# 0       0.657152        NaN
# 1       0.800000        NaN
# 2      -0.500000        NaN
# 3      -0.890000        NaN
# 4       0.360000        NaN
# 5      -0.517000        NaN
# 6       1.000000        NaN
# 7       0.500000        NaN
# 8       4.040000        NaN
# 9       1.000000        NaN
# 10     -2.860000        NaN
# 11      1.440000        NaN
# 12      0.780000        NaN
# 13     -0.090000        NaN
# 14      2.385000        NaN
# 15     -0.400000        NaN
# 16      3.281000        NaN
# 17     -2.150000        NaN
# 18     -0.860000        NaN
# 19      0.361000        NaN
# 20     -0.650000        NaN
# 21     -2.300000        NaN
# 22     -1.540000        NaN
# 23      1.090900        NaN
# 24     -0.650000        NaN
# 25     -0.026000        NaN
# 26      0.240000        NaN
# 27      1.100000        NaN
# 28     -2.100000        NaN
# 29     -0.780000        NaN
# 30      0.421390        NaN
# 31      2.830000        NaN
# 32     -0.570000        NaN
# 33      0.220000        NaN
# 34     -0.790000        NaN
# 35     -0.300000        NaN
# 36     -0.480000        NaN
# 37     -1.110000        NaN
# 38      0.660000        NaN
